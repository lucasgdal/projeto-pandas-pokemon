# %%
import pandas as pd

# %%
pokemon_df = pd.read_csv('pokemon.csv')

# %%
pokemon_df.rename(columns={'national_number':'Nº'},inplace=True)

# %%
pokemon_df.head(10)
# Out:
#    Nº gen        Name primary_type secondary_type percent_male percent_female  \
# 0   1   I   Bulbasaur        grass         poison        88.14          11.86
# 1   2   I     Ivysaur        grass         poison        88.14          11.86
# 2   3   I    Venusaur        grass         poison        88.14          11.86
# 3   4   I  Charmander         fire            NaN        88.14          11.86
# 4   5   I  Charmeleon         fire            NaN        88.14          11.86
# 5   6   I   Charizard         fire         flying        88.14          11.86
# 6   7   I    Squirtle        water            NaN        88.14          11.86
# 7   8   I   Wartortle        water            NaN        88.14          11.86
# 8   9   I   Blastoise        water            NaN        88.14          11.86
# 9  10   I    Caterpie          bug            NaN         50.2           49.8
#
#    height_m  weight_kg capture_rate  ...  against_dragon  against_dark  \
# 0       0.7        6.9           45  ...             1.0           1.0
# 1       1.0       13.0           45  ...             1.0           1.0
# 2       2.0      100.0           45  ...             1.0           1.0
# 3       0.6        8.5           45  ...             1.0           1.0
# 4       1.1       19.0           45  ...             1.0           1.0
# 5       1.7       90.5           45  ...             1.0           1.0
# 6       0.5        9.0           45  ...             1.0           1.0
# 7       1.0       22.5           45  ...             1.0           1.0
# 8       1.6       85.5           45  ...             1.0           1.0
# 9       0.3        2.9          255  ...             1.0           1.0
#
#    against_steel  against_fairy  is_sublegendary  is_legendary  is_mythical  \
# 0            1.0            0.5                0             0            0
# 1            1.0            0.5                0             0            0
# 2            1.0            0.5                0             0            0
# 3            0.5            0.5                0             0            0
# 4            0.5            0.5                0             0            0
# 5            0.5            0.5                0             0            0
# 6            0.5            1.0                0             0            0
# 7            0.5            1.0                0             0            0
# 8            0.5            1.0                0             0            0
# 9            1.0            1.0                0             0            0
#
#              gigantamax    mega_evolution mega_evolution_alt
# 0                   NaN               NaN                NaN
# 1                   NaN               NaN                NaN
# 2   Gigantamax Venusaur     Mega Venusaur                NaN
# 3                   NaN               NaN                NaN
# 4                   NaN               NaN                NaN
# 5  Gigantamax Charizard  Mega Charizard X   Mega Charizard Y
# 6                   NaN               NaN                NaN
# 7                   NaN               NaN                NaN
# 8  Gigantamax Blastoise    Mega Blastoise                NaN
# 9                   NaN               NaN                NaN
#
# [10 rows x 45 columns]

# %% [markdown]
# # Ranking dos melhores Pokémon de cada tipo por Atríbuto

# %% [markdown]
# Informe o tipo do Pokemon

# %%
tipo = input('Informe o tipo do pokemon (em ingês): ')
# Out:
# Informe o tipo do pokemon (em ingês): dragon

# %%
selecao_tipo = (pokemon_df['primary_type'] == tipo) & (pokemon_df['gen'] != 'VIII') & (pokemon_df['gen'] != 'VII') & (pokemon_df['gen'] != 'VI')
pokemon_tipo = pokemon_df[selecao_tipo]

# %%
quantidade_pokemon=pokemon_tipo.shape[0]
print(f'Pokémon tipo: {tipo}')
print(f'Quantidade de Pokémon do tipo escolhido: {quantidade_pokemon}')
# Out:
# Pokémon tipo: dragon
# Quantidade de Pokémon do tipo escolhido: 20

# %%
ranking_tipo = pokemon_tipo[['Nº','gen','Name','primary_type','height_m','weight_kg','hp','attack','defense','sp_attack','sp_defense','speed']]

# %% [markdown]
# # Top 10 Pokémon - Melhor HP

# %%
ranking_tipo.sort_values('hp',ascending=False,ignore_index=True).head(10)
# Out:
#     Nº  gen       Name primary_type  height_m  weight_kg   hp  attack  \
# 0  646    V     Kyurem       dragon       3.0      325.0  125     130
# 1  445   IV   Garchomp       dragon       1.9       95.0  108     130
# 2  384  III   Rayquaza       dragon       7.0      206.5  105     150
# 3  644    V     Zekrom       dragon       2.9      345.0  100     150
# 4  643    V   Reshiram       dragon       3.2      330.0  100     120
# 5  373  III  Salamence       dragon       1.5      102.6   95     135
# 6  149    I  Dragonite       dragon       2.2      210.0   91     134
# 7  380  III     Latias       dragon       1.4       40.0   80      80
# 8  381  III     Latios       dragon       2.0       60.0   80      90
# 9  621    V  Druddigon       dragon       1.6      139.0   77     120
#
#    defense  sp_attack  sp_defense  speed
# 0       90        130          90     95
# 1       95         80          85    102
# 2       90        150          90     95
# 3      120        120         100     90
# 4      100        150         120     90
# 5       80        110          80    100
# 6       95        100         100     80
# 7       90        110         130    110
# 8       80        130         110    110
# 9       90         60          90     48

# %% [markdown]
# # Top 10 Pokémon - Melhor Ataque

# %%
ranking_tipo.sort_values('attack',ascending=False,ignore_index=True).head(10)
# Out:
#     Nº  gen       Name primary_type  height_m  weight_kg   hp  attack  \
# 0  644    V     Zekrom       dragon       2.9      345.0  100     150
# 1  384  III   Rayquaza       dragon       7.0      206.5  105     150
# 2  612    V    Haxorus       dragon       1.8      105.5   76     147
# 3  373  III  Salamence       dragon       1.5      102.6   95     135
# 4  149    I  Dragonite       dragon       2.2      210.0   91     134
# 5  646    V     Kyurem       dragon       3.0      325.0  125     130
# 6  445   IV   Garchomp       dragon       1.9       95.0  108     130
# 7  643    V   Reshiram       dragon       3.2      330.0  100     120
# 8  621    V  Druddigon       dragon       1.6      139.0   77     120
# 9  611    V    Fraxure       dragon       1.0       36.0   66     117
#
#    defense  sp_attack  sp_defense  speed
# 0      120        120         100     90
# 1       90        150          90     95
# 2       90         60          70     97
# 3       80        110          80    100
# 4       95        100         100     80
# 5       90        130          90     95
# 6       95         80          85    102
# 7      100        150         120     90
# 8       90         60          90     48
# 9       70         40          50     67

# %% [markdown]
# # Top 10 Pokémon - Melhor Defesa

# %%
ranking_tipo.sort_values('defense',ascending=False,ignore_index=True).head(10)
# Out:
#     Nº  gen       Name primary_type  height_m  weight_kg   hp  attack  \
# 0  644    V     Zekrom       dragon       2.9      345.0  100     150
# 1  643    V   Reshiram       dragon       3.2      330.0  100     120
# 2  372  III    Shelgon       dragon       1.1      110.5   65      95
# 3  149    I  Dragonite       dragon       2.2      210.0   91     134
# 4  445   IV   Garchomp       dragon       1.9       95.0  108     130
# 5  621    V  Druddigon       dragon       1.6      139.0   77     120
# 6  612    V    Haxorus       dragon       1.8      105.5   76     147
# 7  646    V     Kyurem       dragon       3.0      325.0  125     130
# 8  380  III     Latias       dragon       1.4       40.0   80      80
# 9  334  III    Altaria       dragon       1.1       20.6   75      70
#
#    defense  sp_attack  sp_defense  speed
# 0      120        120         100     90
# 1      100        150         120     90
# 2      100         60          50     50
# 3       95        100         100     80
# 4       95         80          85    102
# 5       90         60          90     48
# 6       90         60          70     97
# 7       90        130          90     95
# 8       90        110         130    110
# 9       90         70         105     80

# %% [markdown]
# # Top 10 Pokémon - Melhor Ataque Especial

# %%
ranking_tipo.sort_values('sp_attack',ascending=False,ignore_index=True).head(10)
# Out:
#     Nº  gen       Name primary_type  height_m  weight_kg   hp  attack  \
# 0  384  III   Rayquaza       dragon       7.0      206.5  105     150
# 1  643    V   Reshiram       dragon       3.2      330.0  100     120
# 2  646    V     Kyurem       dragon       3.0      325.0  125     130
# 3  381  III     Latios       dragon       2.0       60.0   80      90
# 4  644    V     Zekrom       dragon       2.9      345.0  100     150
# 5  373  III  Salamence       dragon       1.5      102.6   95     135
# 6  380  III     Latias       dragon       1.4       40.0   80      80
# 7  149    I  Dragonite       dragon       2.2      210.0   91     134
# 8  445   IV   Garchomp       dragon       1.9       95.0  108     130
# 9  334  III    Altaria       dragon       1.1       20.6   75      70
#
#    defense  sp_attack  sp_defense  speed
# 0       90        150          90     95
# 1      100        150         120     90
# 2       90        130          90     95
# 3       80        130         110    110
# 4      120        120         100     90
# 5       80        110          80    100
# 6       90        110         130    110
# 7       95        100         100     80
# 8       95         80          85    102
# 9       90         70         105     80

# %% [markdown]
# # Top 10 Pokémon - Melhor Defesa Especial

# %%
ranking_tipo.sort_values('sp_defense',ascending=False,ignore_index=True).head(10)
# Out:
#     Nº  gen       Name primary_type  height_m  weight_kg   hp  attack  \
# 0  380  III     Latias       dragon       1.4       40.0   80      80
# 1  643    V   Reshiram       dragon       3.2      330.0  100     120
# 2  381  III     Latios       dragon       2.0       60.0   80      90
# 3  334  III    Altaria       dragon       1.1       20.6   75      70
# 4  149    I  Dragonite       dragon       2.2      210.0   91     134
# 5  644    V     Zekrom       dragon       2.9      345.0  100     150
# 6  646    V     Kyurem       dragon       3.0      325.0  125     130
# 7  384  III   Rayquaza       dragon       7.0      206.5  105     150
# 8  621    V  Druddigon       dragon       1.6      139.0   77     120
# 9  445   IV   Garchomp       dragon       1.9       95.0  108     130
#
#    defense  sp_attack  sp_defense  speed
# 0       90        110         130    110
# 1      100        150         120     90
# 2       80        130         110    110
# 3       90         70         105     80
# 4       95        100         100     80
# 5      120        120         100     90
# 6       90        130          90     95
# 7       90        150          90     95
# 8       90         60          90     48
# 9       95         80          85    102

# %% [markdown]
# # Top 10 Pokémon - Melhor Velocidade

# %%
ranking_tipo.sort_values('speed',ascending=False,ignore_index=True).head(10)
# Out:
#     Nº  gen       Name primary_type  height_m  weight_kg   hp  attack  \
# 0  380  III     Latias       dragon       1.4       40.0   80      80
# 1  381  III     Latios       dragon       2.0       60.0   80      90
# 2  445   IV   Garchomp       dragon       1.9       95.0  108     130
# 3  373  III  Salamence       dragon       1.5      102.6   95     135
# 4  612    V    Haxorus       dragon       1.8      105.5   76     147
# 5  646    V     Kyurem       dragon       3.0      325.0  125     130
# 6  384  III   Rayquaza       dragon       7.0      206.5  105     150
# 7  644    V     Zekrom       dragon       2.9      345.0  100     150
# 8  643    V   Reshiram       dragon       3.2      330.0  100     120
# 9  444   IV     Gabite       dragon       1.4       56.0   68      90
#
#    defense  sp_attack  sp_defense  speed
# 0       90        110         130    110
# 1       80        130         110    110
# 2       95         80          85    102
# 3       80        110          80    100
# 4       90         60          70     97
# 5       90        130          90     95
# 6       90        150          90     95
# 7      120        120         100     90
# 8      100        150         120     90
# 9       65         50          55     82
